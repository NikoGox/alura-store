# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

print(tienda.shape)
print(tienda2.shape)
print(tienda3.shape)
print(tienda4.shape)

tienda.head()
# Out:
# (2359, 12)
# (2359, 12)
# (2359, 12)
# (2358, 12)
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
# Exploración de los DataFrames
import pandas as pd

# Mostrar las primeras 5 filas de cada tienda
print("********* Tiendas *********")

print("Tienda 1 - Primeras filas:")
print(tienda.head())
print("\nTienda 2 - Primeras filas:")
print(tienda2.head())
print("\nTienda 3 - Primeras filas:")
print(tienda3.head())
print("\nTienda 4 - Primeras filas:")
print(tienda4.head())

# Información de columnas y tipos de datos

print("********* Informacion de las tiendas *********")

print("\nInformación de Tienda 1:")
print(tienda.info())
print("\nInformación de Tienda 2:")
print(tienda2.info())
print("\nInformación de Tienda 3:")
print(tienda3.info())
print("\nInformación de Tienda 4:")
print(tienda4.info())

# Resumen estadístico de columnas numéricas

print("********* Resumen estadistico por tienda *********")

print("\nResumen estadístico de Tienda 1:")
print(tienda.describe())
print("\nResumen estadístico de Tienda 2:")
print(tienda2.describe())
print("\nResumen estadístico de Tienda 3:")
print(tienda3.describe())
print("\nResumen estadístico de Tienda 4:")
print(tienda4.describe())

# Verificar valores nulos
print("********* Valores nulos *********")

print("\nValores nulos en Tienda 1:")
print(tienda.isnull().sum())
print("\nValores nulos en Tienda 2:")
print(tienda2.isnull().sum())
print("\nValores nulos en Tienda 3:")
print(tienda3.isnull().sum())
print("\nValores nulos en Tienda 4:")
print(tienda4.isnull().sum())

# Listar columnas
print("\nColumnas de Tienda 1:")
print(tienda.columns)
# Out:
# ********* Tiendas *********
# Tienda 1 - Primeras filas:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %% [markdown]
# ## Exploración de Datos
#
# ### Estructura de los Datos
# - **Columnas**: Producto, Categoría del Producto, Precio, Costo de envío, Fecha de Compra, Vendedor, Lugar de Compra, Calificación, Método de pago, Cantidad de cuotas, lat, lon.
# - **Número de filas**:
#   - Tienda 1: [reemplaza con el resultado de tienda.shape[0]]
#   - Tienda 2: [reemplaza con el resultado de tienda2.shape[0]]
#   - Tienda 3: [reemplaza con el resultado de tienda3.shape[0]]
#   - Tienda 4: [reemplaza con el resultado de tienda4.shape[0]]
# - **Tipos de datos**: Precio y Costo de envío (float64), Calificación y Cantidad de cuotas (int64), Fecha de Compra y otras categóricas (object), lat y lon (float64).
#
# ### Observaciones
# - **Valores nulos**: [Indica si hay nulos o no, por ejemplo, "No se encontraron valores nulos en ninguna tienda"].
# - **Rangos**:
#   - Precios: [Mínimo y máximo observados, por ejemplo, "entre 7,600 y 2,977,000 en Tienda 1"].
#   - Costos de envío: [Mínimo y máximo].
#   - Calificaciones: Entre 1 y 5.
# - **Categorías**: Incluyen Electrónicos, Muebles, Juguetes, Electrodomésticos, [otras categorías si las ves].
# - **Métodos de pago**: Tarjeta de crédito, Nequi, [otros si los ves].
# - **Patrones**: [Por ejemplo, "Tienda 1 tiene productos caros como Microondas, Tienda 2 parece tener más variedad"].
#
# ### Notas para el análisis
# - Usar `Precio` para calcular ingresos totales.
# - Agrupar por `Categoría del Producto` para ventas por categoría.
# - Usar `Calificación` para promedio de valoraciones.
# - Contar `Producto` para productos más/menos vendidos.
# - Usar `Costo de envío` para promedio por tienda.

# %% [markdown]
# #1. Análisis de facturación

# %%
import matplotlib.pyplot as plt


# 1. Análisis de facturación
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

ingresos_totales = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]
})

# Mostrar los ingresos totales
print("Ingresos totales por tienda:")
print(ingresos_totales)

# Crear un gráfico de barras para los ingresos totales por tienda
plt.figure(figsize=(6, 4))
plt.bar(ingresos_totales['Tienda'], ingresos_totales['Ingreso Total'], color=['skyblue', 'lightgreen', 'lightcoral', 'yellow'])
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Guardar los datos en un archivo CSV
ingresos_totales.to_csv('ingresos_totales.csv', index=False)
# Out:
# Ingresos totales por tienda:
#      Tienda  Ingreso Total
# 0  Tienda 1   1.150880e+09
# 1  Tienda 2   1.116344e+09
# 2  Tienda 3   1.098020e+09
# 3  Tienda 4   1.038376e+09

# %% [markdown]
# Los ingresos totales de cada tienda muestran que Tienda 1 tiene el mayor ingreso con 1.150 millones, seguida de Tienda 2 con 1.116 millones. Las Tiendas 3 y 4 presentan ingresos similares, alrededor de 1.098 millones y 1.038 millones, respectivamente. Esto indica que, en términos generales, la Tienda 1 tiene un rendimiento más alto, aunque la diferencia no es drástica, lo que podría significar que todas las tiendas están manteniendo un nivel de ventas competitivo.

# %% [markdown]
# # 2. Ventas por categoría

# %%
# 2. Ventas por categoría
ventas_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index()
ventas_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().reset_index()
ventas_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().reset_index()
ventas_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().reset_index()

ventas_categoria_tienda1.columns = ['Categoría', 'Ingreso Tienda 1']
ventas_categoria_tienda2.columns = ['Categoría', 'Ingreso Tienda 2']
ventas_categoria_tienda3.columns = ['Categoría', 'Ingreso Tienda 3']
ventas_categoria_tienda4.columns = ['Categoría', 'Ingreso Tienda 4']

ventas_categorias = ventas_categoria_tienda1.merge(
    ventas_categoria_tienda2, on='Categoría', how='outer'
).merge(
    ventas_categoria_tienda3, on='Categoría', how='outer'
).merge(
    ventas_categoria_tienda4, on='Categoría', how='outer'
).fillna(0)

print("Ventas por categoría para cada tienda:")
print(ventas_categorias)

# Crear gráfico de barras para visualizar las ventas por categoría en cada tienda
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
ventas_categorias.set_index('Categoría').plot(kind='bar', stacked=False)
plt.title('Ventas por Categoría en Cada Tienda')
plt.xlabel('Categoría del Producto')
plt.ylabel('Ingreso Total')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Guardar los datos en un archivo CSV
ventas_categorias.to_csv('ventas_categorias.csv', index=False)
# Out:
# Ventas por categoría para cada tienda:
#                  Categoría  Ingreso Tienda 1  Ingreso Tienda 2  \
# 0  Artículos para el hogar        12698400.0        14746900.0
# 1     Deportes y diversión        39290000.0        34744500.0
# 2        Electrodomésticos       363685200.0       348567800.0
# 3             Electrónicos       429493500.0       410831100.0
# 4   Instrumentos musicales        91299000.0       104990300.0
# 5                 Juguetes        17995700.0        15945400.0
# 6                   Libros         8784900.0        10091200.0
# 7                  Muebles       187633700.0       176426300.0
#
#    Ingreso Tienda 3  Ingreso Tienda 4
# 0        15060000.0        15074500.0
# 1        35593100.0        33350100.0
# 2       329237900.0       283260200.0
# 3       410775800.0       409476100.0
# 4        77380900.0        75102400.0
# 5        19401100.0        20262200.0
# 6         9498700.0         9321300.0
# 7       201072100.0       192528900.0

# %% [markdown]
# El análisis de ventas por categoría revela que Electrodomésticos y Electrónicos son las categorías más fuertes en términos de ingresos, especialmente para Tienda 1 y Tienda 2, con ventas significativas en ambas. Sin embargo, Instrumentos musicales y Juguetes tienen ingresos más bajos, sugiriendo que estas categorías podrían necesitar más promoción o una oferta más atractiva para incrementar su rendimiento. Las diferencias en ingresos por tienda en categorías específicas también pueden reflejar variaciones en el mercado y las preferencias regionales.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# 3. Calificación promedio de la tienda
calificacion_tienda1 = tienda['Calificación'].mean()
calificacion_tienda2 = tienda2['Calificación'].mean()
calificacion_tienda3 = tienda3['Calificación'].mean()
calificacion_tienda4 = tienda4['Calificación'].mean()

calificaciones_promedio = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Calificación Promedio': [calificacion_tienda1, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]
})

print("Calificación promedio por tienda:")
print(calificaciones_promedio)

# Crear gráfico de barras para visualizar las calificaciones promedio de cada tienda
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(calificaciones_promedio['Tienda'], calificaciones_promedio['Calificación Promedio'], color='skyblue')
plt.title('Calificación Promedio de las Tiendas')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.ylim(0, 5)  # Asumiendo que la calificación es sobre 5
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# Calificación promedio por tienda:
#      Tienda  Calificación Promedio
# 0  Tienda 1               3.976685
# 1  Tienda 2               4.037304
# 2  Tienda 3               4.048326
# 3  Tienda 4               3.995759

# %% [markdown]
# Las calificaciones promedio de las tiendas están bastante equilibradas, con Tienda 3 teniendo la calificación más alta (4.05), seguida por Tienda 2 (4.04). Esto sugiere que los clientes están generalmente satisfechos con las compras y experiencias en estas tiendas. Sin embargo, Tienda 1 y Tienda 4 tienen calificaciones ligeramente más bajas, lo que podría implicar áreas de mejora en la atención al cliente o en la experiencia general de compra.

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# 4. Productos más y menos vendidos
ventas_productos_tienda1 = tienda['Producto'].value_counts().reset_index()
ventas_productos_tienda2 = tienda2['Producto'].value_counts().reset_index()
ventas_productos_tienda3 = tienda3['Producto'].value_counts().reset_index()
ventas_productos_tienda4 = tienda4['Producto'].value_counts().reset_index()

ventas_productos_tienda1.columns = ['Producto', 'Ventas Tienda 1']
ventas_productos_tienda2.columns = ['Producto', 'Ventas Tienda 2']
ventas_productos_tienda3.columns = ['Producto', 'Ventas Tienda 3']
ventas_productos_tienda4.columns = ['Producto', 'Ventas Tienda 4']

mas_vendidos_tienda1 = ventas_productos_tienda1.head(1)
menos_vendidos_tienda1 = ventas_productos_tienda1.tail(1)
mas_vendidos_tienda2 = ventas_productos_tienda2.head(1)
menos_vendidos_tienda2 = ventas_productos_tienda2.tail(1)
mas_vendidos_tienda3 = ventas_productos_tienda3.head(1)
menos_vendidos_tienda3 = ventas_productos_tienda3.tail(1)
mas_vendidos_tienda4 = ventas_productos_tienda4.head(1)
menos_vendidos_tienda4 = ventas_productos_tienda4.tail(1)

productos_extremos = pd.concat([
    mas_vendidos_tienda1.assign(Tienda='Tienda 1', Tipo='Más Vendido'),
    menos_vendidos_tienda1.assign(Tienda='Tienda 1', Tipo='Menos Vendido'),
    mas_vendidos_tienda2.assign(Tienda='Tienda 2', Tipo='Más Vendido'),
    menos_vendidos_tienda2.assign(Tienda='Tienda 2', Tipo='Menos Vendido'),
    mas_vendidos_tienda3.assign(Tienda='Tienda 3', Tipo='Más Vendido'),
    menos_vendidos_tienda3.assign(Tienda='Tienda 3', Tipo='Menos Vendido'),
    mas_vendidos_tienda4.assign(Tienda='Tienda 4', Tipo='Más Vendido'),
    menos_vendidos_tienda4.assign(Tienda='Tienda 4', Tipo='Menos Vendido')
])

print("Productos más y menos vendidos por tienda:")
print(productos_extremos)
# Out:
# Productos más y menos vendidos por tienda:
#                      Producto  Ventas Tienda 1    Tienda           Tipo  \
# 0                  Microondas             60.0  Tienda 1    Más Vendido
# 50               Celular ABXY             33.0  Tienda 1  Menos Vendido
# 0   Iniciando en programación              NaN  Tienda 2    Más Vendido
# 50              Juego de mesa              NaN  Tienda 2  Menos Vendido
# 0               Kit de bancas              NaN  Tienda 3    Más Vendido
# 50    Bloques de construcción              NaN  Tienda 3  Menos Vendido
# 0                    Cama box              NaN  Tienda 4    Más Vendido
# 50         Guitarra eléctrica              NaN  Tienda 4  Menos Vendido
#
#     Ventas Tienda 2  Ventas Tienda 3  Ventas Tienda 4
# 0               NaN              NaN              NaN
# 50              NaN              NaN              NaN
# 0              65.0              NaN              NaN
# 50             32.0              NaN              NaN
# ...

# %% [markdown]
# El análisis de los productos más y menos vendidos destaca algunos productos clave que impulsan las ventas. Tienda 1 tiene el Microondas como su producto más vendido, lo que refleja una fuerte demanda de electrodomésticos, mientras que el Celular ABXY es el menos vendido. Tienda 2, Tienda 3 y Tienda 4 presentan productos con un rendimiento más variado, pero no hay un patrón claro debido a la falta de datos en algunos productos. Este análisis sugiere que las tiendas pueden beneficiarse de una mayor estrategia de promoción o ajuste en los productos menos vendidos, como el Juego de mesa y el Bloques de construcción.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 4. Productos más y menos vendidos
ventas_productos_tienda1 = tienda['Producto'].value_counts().reset_index()
ventas_productos_tienda2 = tienda2['Producto'].value_counts().reset_index()
ventas_productos_tienda3 = tienda3['Producto'].value_counts().reset_index()
ventas_productos_tienda4 = tienda4['Producto'].value_counts().reset_index()

ventas_productos_tienda1.columns = ['Producto', 'Ventas Tienda 1']
ventas_productos_tienda2.columns = ['Producto', 'Ventas Tienda 2']
ventas_productos_tienda3.columns = ['Producto', 'Ventas Tienda 3']
ventas_productos_tienda4.columns = ['Producto', 'Ventas Tienda 4']

# Encontramos los productos más y menos vendidos
mas_vendidos_tienda1 = ventas_productos_tienda1.iloc[ventas_productos_tienda1['Ventas Tienda 1'].idxmax()]
menos_vendidos_tienda1 = ventas_productos_tienda1.iloc[ventas_productos_tienda1['Ventas Tienda 1'].idxmin()]

mas_vendidos_tienda2 = ventas_productos_tienda2.iloc[ventas_productos_tienda2['Ventas Tienda 2'].idxmax()]
menos_vendidos_tienda2 = ventas_productos_tienda2.iloc[ventas_productos_tienda2['Ventas Tienda 2'].idxmin()]

mas_vendidos_tienda3 = ventas_productos_tienda3.iloc[ventas_productos_tienda3['Ventas Tienda 3'].idxmax()]
menos_vendidos_tienda3 = ventas_productos_tienda3.iloc[ventas_productos_tienda3['Ventas Tienda 3'].idxmin()]

mas_vendidos_tienda4 = ventas_productos_tienda4.iloc[ventas_productos_tienda4['Ventas Tienda 4'].idxmax()]
menos_vendidos_tienda4 = ventas_productos_tienda4.iloc[ventas_productos_tienda4['Ventas Tienda 4'].idxmin()]

# Convertimos las Series a DataFrame
mas_vendidos_tienda1 = pd.DataFrame([mas_vendidos_tienda1]).assign(Tienda='Tienda 1', Tipo='Más Vendido')
menos_vendidos_tienda1 = pd.DataFrame([menos_vendidos_tienda1]).assign(Tienda='Tienda 1', Tipo='Menos Vendido')

mas_vendidos_tienda2 = pd.DataFrame([mas_vendidos_tienda2]).assign(Tienda='Tienda 2', Tipo='Más Vendido')
menos_vendidos_tienda2 = pd.DataFrame([menos_vendidos_tienda2]).assign(Tienda='Tienda 2', Tipo='Menos Vendido')

mas_vendidos_tienda3 = pd.DataFrame([mas_vendidos_tienda3]).assign(Tienda='Tienda 3', Tipo='Más Vendido')
menos_vendidos_tienda3 = pd.DataFrame([menos_vendidos_tienda3]).assign(Tienda='Tienda 3', Tipo='Menos Vendido')

mas_vendidos_tienda4 = pd.DataFrame([mas_vendidos_tienda4]).assign(Tienda='Tienda 4', Tipo='Más Vendido')
menos_vendidos_tienda4 = pd.DataFrame([menos_vendidos_tienda4]).assign(Tienda='Tienda 4', Tipo='Menos Vendido')

# Concatenamos todos los DataFrames
productos_extremos = pd.concat([
    mas_vendidos_tienda1,
    menos_vendidos_tienda1,
    mas_vendidos_tienda2,
    menos_vendidos_tienda2,
    mas_vendidos_tienda3,
    menos_vendidos_tienda3,
    mas_vendidos_tienda4,
    menos_vendidos_tienda4
])

# Mostrar el análisis completo
print("Productos más y menos vendidos por tienda:")
print(productos_extremos)

# Ahora verificamos que los productos sean consistentes entre las tiendas
# Filtrar por productos que realmente existen en cada tienda

# Preparar las listas para la gráfica
productos = productos_extremos['Producto'].unique()
pos = range(len(productos))

# Crear gráfico de barras
plt.figure(figsize=(12, 8))

# Colores
color_mas_vendido = 'green'
color_menos_vendido = 'red'

# Inicializar las posiciones
pos_mas_vendido = []
pos_menos_vendido = []

# Definir la posición de las barras para cada tienda
for i, tienda in enumerate(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']):
    # Filtrar los productos más y menos vendidos para la tienda actual
    mas_vendidos = productos_extremos[(productos_extremos['Tienda'] == tienda) & (productos_extremos['Tipo'] == 'Más Vendido')]
    menos_vendidos = productos_extremos[(productos_extremos['Tienda'] == tienda) & (productos_extremos['Tipo'] == 'Menos Vendido')]

    # Añadir las posiciones de las barras
    pos_mas_vendido.append(i * 4)  # Multiplicamos por 4 para distribuir los datos de las 4 tiendas
    pos_menos_vendido.append(i * 4 + 1)

    # Dibujar las barras
    plt.barh(pos_mas_vendido[i], mas_vendidos['Ventas Tienda 1'].values[0] if tienda == 'Tienda 1' else mas_vendidos['Ventas Tienda 2'].values[0] if tienda == 'Tienda 2' else mas_vendidos['Ventas Tienda 3'].values[0] if tienda == 'Tienda 3' else mas_vendidos['Ventas Tienda 4'].values[0], color=color_mas_vendido)
    plt.barh(pos_menos_vendido[i], menos_vendidos['Ventas Tienda 1'].values[0] if tienda == 'Tienda 1' else menos_vendidos['Ventas Tienda 2'].values[0] if tienda == 'Tienda 2' else menos_vendidos['Ventas Tienda 3'].values[0] if tienda == 'Tienda 3' else menos_vendidos['Ventas Tienda 4'].values[0], color=color_menos_vendido)

# Añadir etiquetas con los nombres de los productos
plt.yticks(pos_mas_vendido + pos_menos_vendido, productos_extremos['Producto'].values, rotation=0)

plt.title('Productos Más y Menos Vendidos por Tienda')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Producto')

# Mostrar gráfico
plt.tight_layout()
plt.show()
# Out:
# Productos más y menos vendidos por tienda:
#                      Producto  Ventas Tienda 1    Tienda           Tipo  \
# 0                  Microondas             60.0  Tienda 1    Más Vendido
# 49  Auriculares con micrófono             33.0  Tienda 1  Menos Vendido
# 0   Iniciando en programación              NaN  Tienda 2    Más Vendido
# 50              Juego de mesa              NaN  Tienda 2  Menos Vendido
# 0               Kit de bancas              NaN  Tienda 3    Más Vendido
# 50    Bloques de construcción              NaN  Tienda 3  Menos Vendido
# 0                    Cama box              NaN  Tienda 4    Más Vendido
# 50         Guitarra eléctrica              NaN  Tienda 4  Menos Vendido
#
#     Ventas Tienda 2  Ventas Tienda 3  Ventas Tienda 4
# 0               NaN              NaN              NaN
# 49              NaN              NaN              NaN
# 0              65.0              NaN              NaN
# 50             32.0              NaN              NaN
# ...

# %% [markdown]
# En términos de costos de envío, Tienda 1 tiene el costo promedio más alto (26,018), seguido de cerca por Tienda 2 (25,216). Esto podría implicar que algunas tiendas están incurriendo en mayores costos logísticos que otras. Las tiendas deberían explorar oportunidades para optimizar sus procesos de envío y reducir estos costos, lo cual podría mejorar su rentabilidad. Tienda 3 y Tienda 4 tienen costos de envío más bajos, lo que sugiere que están manejando sus operaciones logísticas de manera más eficiente.

# %% [markdown]
# # Informe Final: Análisis de Tiendas para la Decisión de Venta
# Introducción
# El propósito de este análisis es proporcionar una evaluación detallada de las cuatro tiendas del Sr. Juan, con el fin de determinar cuál de ellas debería ser vendida. Para ello, se han analizado diversos factores clave, como los ingresos totales de cada tienda, el desempeño por categoría de productos, las calificaciones promedio de los clientes, los productos más y menos vendidos, y los costos de envío. A través de este informe, se busca ofrecer una recomendación objetiva y bien fundamentada, respaldada por los datos y visualizaciones generados.
#
# ## Desarrollo
# 1. Ingresos Totales de las Tiendas
#
# Según el análisis de los ingresos, la Tienda 1 es la que presenta el mayor ingreso total, seguida por la Tienda 2. Las Tiendas 3 y Tienda 4 presentan ingresos más bajos, aunque la diferencia no es muy significativa entre ellas, lo que sugiere que, en términos generales, todas las tiendas tienen un rendimiento bastante equilibrado. Sin embargo, Tienda 1 sigue liderando en cuanto a ingresos, mientras que Tienda 4 muestra el rendimiento más bajo en este aspecto.
#
# 2. Categorías de Productos Más y Menos Vendidas
#
# Al observar las categorías de productos más y menos vendidas, se puede ver que las categorías de Electrodomésticos y Electrónicos generan más ventas, especialmente en Tienda 1 y Tienda 2, lo que refleja una buena respuesta por parte de los clientes en estas áreas. Por otro lado, las categorías como Instrumentos musicales y Juguetes tienen un desempeño más bajo, lo que indica que las tiendas podrían enfocarse en mejorar la promoción y visibilidad de estas categorías para diversificar las fuentes de ingresos.
#
# 3. Calificación Promedio de los Clientes
#
# Las calificaciones promedio de los clientes en general son positivas, con Tienda 3 destacándose como la mejor calificada con un puntaje de 4.05. Tienda 1, por otro lado, tiene la calificación más baja con un 3.98. Aunque la diferencia es pequeña, esto sugiere que, si bien la Tienda 1 tiene un rendimiento alto en ingresos, podría mejorar en términos de atención al cliente, lo que contribuiría a elevar su calificación promedio y, posiblemente, sus ventas a largo plazo.
#
# 4. Productos Más y Menos Vendidos
#
# En términos de los productos más y menos vendidos, Tienda 1 se destaca por tener al Microondas como el producto más vendido, mientras que el Celular ABXY es el menos vendido. Las otras tiendas muestran una mayor variabilidad en cuanto a sus productos más y menos vendidos, lo que indica que las estrategias de venta y promoción varían entre ellas. Este análisis sugiere que las tiendas deberían centrarse en mejorar la visibilidad de los productos menos vendidos, ajustando sus ofertas y promociones según las demandas específicas de sus consumidores.
#
# 5. Costo de Envío Promedio
#
# En cuanto al costo de envío, la Tienda 1 tiene el costo de envío más alto, lo que puede afectar negativamente sus márgenes de ganancia. Por otro lado, Tienda 4 presenta el costo de envío más bajo, lo que le da una ventaja en términos de rentabilidad. A pesar de esto, el rendimiento general de Tienda 4 en cuanto a ventas y calificación promedio es inferior al de las demás, lo que sugiere que la tienda podría beneficiarse de una mayor atención al cliente y una mejor estrategia de ventas.
#
# ## Conclusión
# ¿Cuál tienda debería vender el Sr. Juan?
#
# Con base en los análisis realizados y los gráficos generados, la Tienda 4 es la que el Sr. Juan debería considerar vender. Aunque la Tienda 4 tiene el costo de envío más bajo, lo que podría sugerir una ventaja en términos de márgenes de ganancia, su rendimiento en ventas y calificación promedio es inferior al de las otras tiendas. A pesar de que las otras tiendas, como Tienda 1, tienen un rendimiento más alto en ingresos, la Tienda 4 no está aprovechando su ventaja en costos de envío, lo que podría estar afectando su competitividad en el mercado.
#
# En consecuencia, al vender Tienda 4, el Sr. Juan podría concentrar sus esfuerzos en mejorar el rendimiento de las otras tiendas, enfocándose en estrategias que aumenten las ventas y la satisfacción del cliente. Esto podría incluir optimización en la promoción de productos, mejora de la atención al cliente, y ajuste en los costos de envío para maximizar la rentabilidad de las tiendas más exitosas.
